# %% [markdown]
# ## Problem 1: Check sign
#
# **Question:** Write a program that checks if a number is positive, negative, or zero.
#
# **Approach:** Think about comparing the number with 0 using if, elif, and else.

# %%
# Enter your answer here
num = int(input("Enter your number : "))
if num > 0:
  print(f"postivie number: {num}")
elif num < 0:
  print(f"negative number:  {num}")
else:
  print("zero")
# Out:
# Enter your number : -7
# negative number -7

# %% [markdown]
# ## Problem 2: Leap Year
#
# **Question:** Check if a given year is a leap year.
#
# **Approach:** Apply the rules: divisible by 4, but centuries must be divisible by 400.
#
# Rules: Year divisible by 4 is leap, but if divisible by 100 it must also be divisible by 400.

# %%
# Enter your answer here
year = int(input(" enter the year :"))
if year % 4 == 0 or (year % 4 == 0 and year % 100 != 0):
  print(f"{year} is a Leap Year")
else:
  print(f"{year} is not a Leap Year")
# Out:
#  enter the year :2016
# 2016 is a Leap Year

# %% [markdown]
# ## Problem 3: Grade Bands
#
# **Question:** Print grade category based on marks: Excellent, Good, Average, Fail.
#
# **Approach:** Build multiple conditions using elif to check ranges.
#
# Take marks (0-100) and print:
# - 90–100 → Excellent
# - 75–89 → Good
# - 50–74 → Average
# - else → Fail

# %%
# Enter your answer here
marks = int(input("Enter the marks : "))
if marks >= 90:
   print("Excellent")
elif marks >= 75 and marks<= 89:
   print("Good")
elif marks >= 50 and marks <= 74:
   print("Average")
else:
  print("Fail")
# Out:
# Enter the marks : 55
# Average

# %% [markdown]
# ## Problem 4: Validate Login
#
# **Question:** Check username=='admin' and password=='1234'.
#
# **Approach:** Use logical AND to validate both conditions.
#
#
# Input: username & password.
#
# If username == 'admin' and password == '1234'
# print 'Login successful',
# else 'Invalid credentials'.

# %%
# Enter your answer here
username = input("Enter username : ")
password = int(input("Enter password : "))
if username == "admin" and password == 1234:
  print("Login successful")
else:
  print("Invalid credentials / please try again")
# Out:
# Enter username :admin
# Enter password : 1234
# Login successful

# %% [markdown]
# ## Problem 5: Movie Ticket Discount
#
# **Question:** Apply discount based on age.
#
# **Approach:** Use ordered elif statements from smallest to largest age group.
#
# Apply discounts based on age:
# - Age < 12 → 50% discount
# - Age between 12 and 18 → 30% discount
# - Age between 18 and 60 → no discount
# - Age > 60 → 40% discount

# %%
# Enter your answer here
age = int(input("Enter your age: "))
if age <12:
  print("50% discount")
elif age>=12 and age<=18:
  print("30% discount")
elif age>= 18 and age<=60:
  print("No discount")
else:
 print("40% discount")
# Out:
# Enter your age: 66
# 40% discount

# %% [markdown]
# ## Problem 6: Placement Eligibility
#
# **Question:** Check CGPA, backlog status, and project count.
#
# **Approach:** All conditions must be true → use AND operator.
#
#
# Conditions:
# - CGPA ≥ 7
# - No backlog (enter 'yes' or 'no')
# - Completed >= 2 major projects
# Print whether the student is eligible.

# %%
# Enter your answer here
cgpa = float(input("Enter your cgpa : "))
backlog = input("Enter your backlog : ")
project_completed = int(input("Enter your project count : "))
if cgpa >= 7 and backlog == "no" and project_completed >= 2:
  print("Congrats you are eligible for Placement")
else:
  print("You are not eligible")
# Out:
# Enter your cgpa : 7.2
# Enter your backlog : no
# Enter your project count : 2
# Congrats you are eligible for Placement

# %% [markdown]
# ## Problem 7: Delivery Charge System
#
# **Question:** Calculate final delivery charge based on prime membership, amount, and distance.
#
# **Approach:** Start with prime-check, then inside it apply nested if blocks.
#
# Inputs:
# - order_amount (int)
# - is_prime_member (yes/no)
# - distance_km (float)
#
# Rules:
# - If prime member → Free delivery
# - Else:
#   - If amount ≥ 500:
#     - If distance ≤ 5 km → Free
#     - Else → ₹20 extra
#   - Else:
#     - If distance ≤ 5 km → ₹30
#     - Else → ₹50

# %%
# Enter your answer here
order_value = float(input("Enter your order value: "))
is_prime_user = input("Enter your membership status Yes or No: ")
distance = float(input("Enter the distance: "))
if is_prime_user == "yes":
  print("Congrats you are eligible for free delivery: ")
elif order_value >= 500 and distance <= 5:
  print("Free delivery")
elif order_value >=  500 and distance >5:
  print("20rs delivery charge applicable")
elif order_value <= 500 and distance <= 5:
  print("30rs delivery charges applicable")
else:
  print("50rs delivery charges applicable")
# Out:
# Enter your order value: 505.66
# Enter your membership status Yes or No: no
# Enter the distance: 3.5
# Free delivery

# %% [markdown]
# ## Problem 8: ATM Withdrawal Simulation
#
# **Question:** Simulate ATM rules: multiples of 100, sufficient balance, manager approval.
#
# **Approach:** Check errors first, then nested conditions for amount > 10000.
#
# Inputs:
# - balance
# - amount
#
# Logic:
# - If amount % 100 != 0 → reject (ATM works with ₹100 multiples)
# - If amount > balance → reject
# - Else:
#   - if amount > 10000 → ask for manager approval
#   - else → withdraw success

# %%
# Enter your answer here
balance = float(input("Enter your balance : "))
amount = float(input("Enter your amount :"))
if (amount%100!= 0):
  print("Reject ATM works with 100rs multiples")
elif amount > balance:
  print("Reject You don't have sufficient balance")
elif amount > 10000:
  print("Ask for manager approval")
else:
  print("Withdraw Success")
# Out:
# Enter your balance : 6000
# Enter your amount :3443
# Reject ATM works with 100rs multiples

# %% [markdown]
# ## Problem 9: Employee Performance Rating
#
# **Question:** Assign performance rating based on sales, feedback, attendance.
#
# **Approach:** Prioritize attendance rule, then apply nested conditions.
#
# Inputs:
# - sales (₹)
# - feedback (0-5 scale)
# - attendance (%)
#
# Logic:
# - If attendance < 70 → 'Poor'
# - Else:
#   - If sales > 100000 AND feedback > 4.5 → 'Excellent'
#   - If sales > 70000 OR feedback > 4 → 'Good'
#   - Else → 'Average'

# %%
# Enter your answer here
sales = float(input("Enter your sales : "))
feedback = float(input("Enter your feedback : "))
attendance = int(input("Enter your attendance : "))
if attendance < 70:
  print("Poor")
elif sales > 100000 and feedback >= 4.5:
  print("Excellent")
elif sales > 70000 or feedback > 4:
  print("Good")
else:
  print("Average")
# Out:
# Enter your sales : 110000
# Enter your feedback : 4.6
# Enter your attendance : 72
# Excellent

# %% [markdown]
# ## Problem 10: Credit Card Eligibility
#
# **Question:** Determine card eligibility based on age, salary, credit score.
#
# **Approach:** First filter by age, then use nested if blocks for salary and credit score.
#
# Inputs:
# - salary
# - credit_score
# - age
#
# Logic:
# - If age < 21 → Not eligible
# - Else:
#   - If salary ≥ 40,000:
#     - If credit_score ≥ 750 → Gold Card
#     - Else → Silver Card
#   - Else:
#     - If credit_score ≥ 800 → Silver Card
#     - Else → Not eligible

# %%
# Enter your answer here
age = int(input("Enter your age : "))
salary = float(input("Enter your salary : "))
credit_score = int(input("Enter your credit score : "))
if age <21:
  print("You are Not Eligible")
elif salary >= 40000 and credit_score >= 750:
  print("Gold Card")
elif salary < 40000 and credit_score >= 800:
  print("Silver Card")
elif credit_score >= 800:
  print("Silver Card")
else:
  print("Not Eligible")
# Out:
# Enter your age : 22
# Enter your salary : 40000
# Enter your credit score : 777
# Gold Card
